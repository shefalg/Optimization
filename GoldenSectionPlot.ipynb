# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
csv='./GoldenSection/Result.csv'

# %%
rs = DataFrame.from_csv(csv)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
#Result.columns = columns=['Function','Runs','Step','RunTime_mean','RunTime_std','Dist_Rel_mean','D_Rel_std','Func_Evaluations']

# %%
rs.plot(x='Step',y=['RunTime_mean','RunTime_std'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
rs[rs.Function=="fun1"].plot(x='Step',y=['RunTime_mean','RunTime_std'])
rs[rs.Function=="fun1"].plot(x='Step',y=['Dist_Rel_mean','D_Rel_std'])
rs[rs.Function=="fun2"].plot(x='Step',y=['RunTime_mean','RunTime_std'])
rs[rs.Function=="fun2"].plot(x='Step',y=['Dist_Rel_mean','D_Rel_std'])
rs[rs.Function=="fun3"].plot(x='Step',y=['RunTime_mean','RunTime_std'])
rs[rs.Function=="fun3"].plot(x='Step',y=['Dist_Rel_mean','D_Rel_std'])
rs[rs.Function=="fun4"].plot(x='Step',y=['RunTime_mean','RunTime_std'])
rs[rs.Function=="fun4"].plot(x='Step',y=['Dist_Rel_mean','D_Rel_std'])
rs[rs.Function=="fun5"].plot(x='Step',y=['RunTime_mean','RunTime_std'])
rs[rs.Function=="fun5"].plot(x='Step',y=['Dist_Rel_mean','D_Rel_std'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label
